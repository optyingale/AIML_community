# %% [markdown]
# ## Week 2: Breast Cancer detection using Machine Learning

# %% [markdown]
# In week 2, we will be implementing the tools we learnt in week 1 on the breast cancer data set. In the second half, we will also learn some of the basic commands from the library scikit learn.

# %% [markdown]
# The Breast Cancer Dataset is available at: https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+%28original%29

# %% [markdown]
# Those who are having trouble downloading the Dataset from the website, the data will be uploaded in the folder and you can directly download from there. In the following few code cells, I will write all the instructions step wise, your assignment for this week is to write codes for the steps simultaneously in your python file and take time to analyze.
# In future projects, you will have to think and come up with these steps alongwith writing the codes.

# %% [markdown]
# #### Step 1: Open the file in your python notebook, print first 5 rows of the dataset and mention what are the dependent and independent variables in the Data.
#
# #### Step 2: Find the statistical parameters of the Data that you have
#
# #### Step 3: Find the shape of the Dataset in hand.
#
# #### Step 4: Find missing values from the Dataset
#
# #### Step 5: Find the value count of B(Benign) and M(Malignant) cancer cells in the column "diagnosis"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----- step 1 -----
df = pd.read_csv("cancer dataset.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#             ...             radius_worst  texture_worst  perimeter_worst  \
# 0           ...                    25.38          17.33           184.60
# 1           ...                    24.99          23.41           158.80
# 2           ...                    23.57          25.53           152.50
# 3           ...                    14.91          26.50            98.87
# 4           ...                    22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# ### There are 10 main features
#
# #### Independent features are
# ##### 1. Radius
# ##### 2. Texture
# ##### 3. Perimeter
# ##### 4. Area
# ##### 5. Smoothness
# ##### 6. Concavity
# ##### 7. Concave points
# ##### 8. Symmetry
# ##### 9. Fractal Dimension
#
# #### Dependent features
# ##### 1. Compactness ((perimeter^2/area)-1.0)
#
# ### These are represented in 3 ways -> mean, standard error and worst

# %%
# ----- step 2 -----
# Statistical Parameters of the dataset
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean           ...             radius_worst  texture_worst  \
# count     569.000000           ...               569.000000     569.000000
# mean        0.181162           ...                16.269190      25.677223
# std         0.027414           ...                 4.833242       6.146258
# min         0.106000           ...                 7.930000      12.020000
# 25%         0.161900           ...                13.010000      21.080000
# 50%         0.179200           ...                14.970000      25.410000
# 75%         0.195700           ...                18.790000      29.720000
# max         0.304000           ...                36.040000      49.540000
#
#        perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        concavity_worst  concave points_worst  symmetry_worst  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        fractal_dimension_worst
# count               569.000000
# mean                  0.083946
# std                   0.018061
# min                   0.055040
# 25%                   0.071460
# 50%                   0.080040
# 75%                   0.092080
# max                   0.207500
#
# [8 rows x 31 columns]

# %%
# ----- step 3 -----
# Shape of the dataset in hand
df.shape
# Out:
# (569, 32)

# %%
# ----- step 4 -----
# Missing values from the dataset
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# ----- alternate for step 4 -----
df.isna().any(axis = 1).value_counts()
# Out:
# False    569
# dtype: int64

# %%
# ----- step 5 -----
# Value count for Malignant/Benign
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# Before proceeding to step 6, we will learn an important concept which is called label encoding. While navigating through the data, you would have seen that the classification has been done in form of words B and M for benign and malignant cancer cells. But we need this to be converted in number so that this parameter can also be used statistically.

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_Y=LabelEncoder()
df.iloc[:,1]=labelencoder_Y.fit_transform(df.iloc[:,1].values)

# %%
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# In the above code, we have applied label encoding on all the rows and one column. This is the syntax, there is nothing much to understand here, so just write this code in your notebook and remeber that whenever you will be needing to convert textual feature in form of numbers, you will be needing this coding and this process is called label encoding.

# %% [markdown]
# #### Step 6: Creating a pairplot and mention the findings
# Before proceeding to creating a pairplot of all the columns, know that the number of columns in the dataset is huge and if we attempt to create a pairplot, either our hardware will not support it or it will crash if it supports. Even if our hardware is able to do so, the pairplot would be so large that it will be virtually impossible to make a sense of the data. Therefore, we will only create a pairplot of first 5 columns and write the findings.
#
# We can do better analysis with the help of correlation matrix.

# %%
import seaborn as sns

# ----- step 6 -----
sns.pairplot(df.iloc[:, 1:7], hue = 'diagnosis')

# %% [markdown]
# #### Step 7: Create a correlation matrix and mention strongly, weakly and negatively correlated quantities.

# %%
# ----- step 7 -----
corr_matrix = df.drop('id',axis=1).corr()

# %%
# ----- step 7 -----
# Strongly correlating features
corr_matrix.where(df.corr()>0.9)
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                      1.0          NaN           NaN             NaN
# radius_mean                    NaN     1.000000           NaN        0.997855
# texture_mean                   NaN          NaN      1.000000             NaN
# perimeter_mean                 NaN     0.997855           NaN        1.000000
# area_mean                      NaN     0.987357           NaN        0.986507
# smoothness_mean                NaN          NaN           NaN             NaN
# compactness_mean               NaN          NaN           NaN             NaN
# concavity_mean                 NaN          NaN           NaN             NaN
# concave points_mean            NaN          NaN           NaN             NaN
# symmetry_mean                  NaN          NaN           NaN             NaN
# fractal_dimension_mean         NaN          NaN           NaN             NaN
# radius_se                      NaN          NaN           NaN             NaN
# texture_se                     NaN          NaN           NaN             NaN
# perimeter_se                   NaN          NaN           NaN             NaN
# area_se                        NaN          NaN           NaN             NaN
# smoothness_se                  NaN          NaN           NaN             NaN
# compactness_se                 NaN          NaN           NaN             NaN
# concavity_se                   NaN          NaN           NaN             NaN
# concave points_se              NaN          NaN           NaN             NaN
# symmetry_se                    NaN          NaN           NaN             NaN
# fractal_dimension_se           NaN          NaN           NaN             NaN
# radius_worst                   NaN     0.969539           NaN        0.969476
# texture_worst                  NaN          NaN      0.912045             NaN
# perimeter_worst                NaN     0.965137           NaN        0.970387
# area_worst                     NaN     0.941082           NaN        0.941550
# smoothness_worst               NaN          NaN           NaN             NaN
# compactness_worst              NaN          NaN           NaN             NaN
# concavity_worst                NaN          NaN           NaN             NaN
# concave points_worst           NaN          NaN           NaN             NaN
# symmetry_worst                 NaN          NaN           NaN             NaN
# fractal_dimension_worst        NaN          NaN           NaN             NaN
#
#                          area_mean  smoothness_mean  compactness_mean  \
# diagnosis                      NaN              NaN               NaN
# radius_mean               0.987357              NaN               NaN
# texture_mean                   NaN              NaN               NaN
# perimeter_mean            0.986507              NaN               NaN
# area_mean                 1.000000              NaN               NaN
# smoothness_mean                NaN              1.0               NaN
# compactness_mean               NaN              NaN               1.0
# concavity_mean                 NaN              NaN               NaN
# concave points_mean            NaN              NaN               NaN
# symmetry_mean                  NaN              NaN               NaN
# fractal_dimension_mean         NaN              NaN               NaN
# radius_se                      NaN              NaN               NaN
# texture_se                     NaN              NaN               NaN
# perimeter_se                   NaN              NaN               NaN
# area_se                        NaN              NaN               NaN
# smoothness_se                  NaN              NaN               NaN
# compactness_se                 NaN              NaN               NaN
# concavity_se                   NaN              NaN               NaN
# concave points_se              NaN              NaN               NaN
# symmetry_se                    NaN              NaN               NaN
# fractal_dimension_se           NaN              NaN               NaN
# radius_worst              0.962746              NaN               NaN
# texture_worst                  NaN              NaN               NaN
# perimeter_worst           0.959120              NaN               NaN
# area_worst                0.959213              NaN               NaN
# smoothness_worst               NaN              NaN               NaN
# compactness_worst              NaN              NaN               NaN
# concavity_worst                NaN              NaN               NaN
# concave points_worst           NaN              NaN               NaN
# symmetry_worst                 NaN              NaN               NaN
# fractal_dimension_worst        NaN              NaN               NaN
#
#                          concavity_mean  concave points_mean  symmetry_mean  \
# diagnosis                           NaN                  NaN            NaN
# radius_mean                         NaN                  NaN            NaN
# texture_mean                        NaN                  NaN            NaN
# perimeter_mean                      NaN                  NaN            NaN
# area_mean                           NaN                  NaN            NaN
# smoothness_mean                     NaN                  NaN            NaN
# compactness_mean                    NaN                  NaN            NaN
# concavity_mean                 1.000000             0.921391            NaN
# concave points_mean            0.921391             1.000000            NaN
# symmetry_mean                       NaN                  NaN            1.0
# fractal_dimension_mean              NaN                  NaN            NaN
# radius_se                           NaN                  NaN            NaN
# texture_se                          NaN                  NaN            NaN
# perimeter_se                        NaN                  NaN            NaN
# area_se                             NaN                  NaN            NaN
# smoothness_se                       NaN                  NaN            NaN
# compactness_se                      NaN                  NaN            NaN
# concavity_se                        NaN                  NaN            NaN
# concave points_se                   NaN                  NaN            NaN
# symmetry_se                         NaN                  NaN            NaN
# fractal_dimension_se                NaN                  NaN            NaN
# radius_worst                        NaN                  NaN            NaN
# texture_worst                       NaN                  NaN            NaN
# perimeter_worst                     NaN                  NaN            NaN
# area_worst                          NaN                  NaN            NaN
# smoothness_worst                    NaN                  NaN            NaN
# compactness_worst                   NaN                  NaN            NaN
# concavity_worst                     NaN                  NaN            NaN
# concave points_worst                NaN             0.910155            NaN
# symmetry_worst                      NaN                  NaN            NaN
# fractal_dimension_worst             NaN                  NaN            NaN
#
#                                   ...             radius_worst  texture_worst  \
# diagnosis                         ...                      NaN            NaN
# radius_mean                       ...                 0.969539            NaN
# texture_mean                      ...                      NaN       0.912045
# perimeter_mean                    ...                 0.969476            NaN
# area_mean                         ...                 0.962746            NaN
# smoothness_mean                   ...                      NaN            NaN
# compactness_mean                  ...                      NaN            NaN
# concavity_mean                    ...                      NaN            NaN
# concave points_mean               ...                      NaN            NaN
# symmetry_mean                     ...                      NaN            NaN
# fractal_dimension_mean            ...                      NaN            NaN
# radius_se                         ...                      NaN            NaN
# texture_se                        ...                      NaN            NaN
# perimeter_se                      ...                      NaN            NaN
# area_se                           ...                      NaN            NaN
# smoothness_se                     ...                      NaN            NaN
# compactness_se                    ...                      NaN            NaN
# concavity_se                      ...                      NaN            NaN
# concave points_se                 ...                      NaN            NaN
# symmetry_se                       ...                      NaN            NaN
# fractal_dimension_se              ...                      NaN            NaN
# radius_worst                      ...                 1.000000            NaN
# texture_worst                     ...                      NaN       1.000000
# perimeter_worst                   ...                 0.993708            NaN
# area_worst                        ...                 0.984015            NaN
# smoothness_worst                  ...                      NaN            NaN
# compactness_worst                 ...                      NaN            NaN
# concavity_worst                   ...                      NaN            NaN
# concave points_worst              ...                      NaN            NaN
# symmetry_worst                    ...                      NaN            NaN
# fractal_dimension_worst           ...                      NaN            NaN
#
#                          perimeter_worst  area_worst  smoothness_worst  \
# diagnosis                            NaN         NaN               NaN
# radius_mean                     0.965137    0.941082               NaN
# texture_mean                         NaN         NaN               NaN
# perimeter_mean                  0.970387    0.941550               NaN
# area_mean                       0.959120    0.959213               NaN
# smoothness_mean                      NaN         NaN               NaN
# compactness_mean                     NaN         NaN               NaN
# concavity_mean                       NaN         NaN               NaN
# concave points_mean                  NaN         NaN               NaN
# symmetry_mean                        NaN         NaN               NaN
# fractal_dimension_mean               NaN         NaN               NaN
# radius_se                            NaN         NaN               NaN
# texture_se                           NaN         NaN               NaN
# perimeter_se                         NaN         NaN               NaN
# area_se                              NaN         NaN               NaN
# smoothness_se                        NaN         NaN               NaN
# compactness_se                       NaN         NaN               NaN
# concavity_se                         NaN         NaN               NaN
# concave points_se                    NaN         NaN               NaN
# symmetry_se                          NaN         NaN               NaN
# fractal_dimension_se                 NaN         NaN               NaN
# radius_worst                    0.993708    0.984015               NaN
# texture_worst                        NaN         NaN               NaN
# perimeter_worst                 1.000000    0.977578               NaN
# area_worst                      0.977578    1.000000               NaN
# smoothness_worst                     NaN         NaN               1.0
# compactness_worst                    NaN         NaN               NaN
# concavity_worst                      NaN         NaN               NaN
# concave points_worst                 NaN         NaN               NaN
# symmetry_worst                       NaN         NaN               NaN
# fractal_dimension_worst              NaN         NaN               NaN
#
#                          compactness_worst  concavity_worst  \
# diagnosis                              NaN              NaN
# radius_mean                            NaN              NaN
# texture_mean                           NaN              NaN
# perimeter_mean                         NaN              NaN
# area_mean                              NaN              NaN
# smoothness_mean                        NaN              NaN
# compactness_mean                       NaN              NaN
# concavity_mean                         NaN              NaN
# concave points_mean                    NaN              NaN
# symmetry_mean                          NaN              NaN
# fractal_dimension_mean                 NaN              NaN
# radius_se                              NaN              NaN
# texture_se                             NaN              NaN
# perimeter_se                           NaN              NaN
# area_se                                NaN              NaN
# smoothness_se                          NaN              NaN
# compactness_se                         NaN              NaN
# concavity_se                           NaN              NaN
# concave points_se                      NaN              NaN
# symmetry_se                            NaN              NaN
# fractal_dimension_se                   NaN              NaN
# radius_worst                           NaN              NaN
# texture_worst                          NaN              NaN
# perimeter_worst                        NaN              NaN
# area_worst                             NaN              NaN
# smoothness_worst                       NaN              NaN
# compactness_worst                      1.0              NaN
# concavity_worst                        NaN              1.0
# concave points_worst                   NaN              NaN
# symmetry_worst                         NaN              NaN
# fractal_dimension_worst                NaN              NaN
#
#                          concave points_worst  symmetry_worst  \
# diagnosis                                 NaN             NaN
# radius_mean                               NaN             NaN
# texture_mean                              NaN             NaN
# perimeter_mean                            NaN             NaN
# area_mean                                 NaN             NaN
# smoothness_mean                           NaN             NaN
# compactness_mean                          NaN             NaN
# concavity_mean                            NaN             NaN
# concave points_mean                  0.910155             NaN
# symmetry_mean                             NaN             NaN
# fractal_dimension_mean                    NaN             NaN
# radius_se                                 NaN             NaN
# texture_se                                NaN             NaN
# perimeter_se                              NaN             NaN
# area_se                                   NaN             NaN
# smoothness_se                             NaN             NaN
# compactness_se                            NaN             NaN
# concavity_se                              NaN             NaN
# concave points_se                         NaN             NaN
# symmetry_se                               NaN             NaN
# fractal_dimension_se                      NaN             NaN
# radius_worst                              NaN             NaN
# texture_worst                             NaN             NaN
# perimeter_worst                           NaN             NaN
# area_worst                                NaN             NaN
# smoothness_worst                          NaN             NaN
# compactness_worst                         NaN             NaN
# concavity_worst                           NaN             NaN
# concave points_worst                 1.000000             NaN
# symmetry_worst                            NaN             1.0
# fractal_dimension_worst                   NaN             NaN
#
#                          fractal_dimension_worst
# diagnosis                                    NaN
# radius_mean                                  NaN
# texture_mean                                 NaN
# perimeter_mean                               NaN
# area_mean                                    NaN
# smoothness_mean                              NaN
# compactness_mean                             NaN
# concavity_mean                               NaN
# concave points_mean                          NaN
# symmetry_mean                                NaN
# fractal_dimension_mean                       NaN
# radius_se                                    NaN
# texture_se                                   NaN
# perimeter_se                                 NaN
# area_se                                      NaN
# smoothness_se                                NaN
# compactness_se                               NaN
# concavity_se                                 NaN
# concave points_se                            NaN
# symmetry_se                                  NaN
# fractal_dimension_se                         NaN
# radius_worst                                 NaN
# texture_worst                                NaN
# perimeter_worst                              NaN
# area_worst                                   NaN
# smoothness_worst                             NaN
# compactness_worst                            NaN
# concavity_worst                              NaN
# concave points_worst                         NaN
# symmetry_worst                               NaN
# fractal_dimension_worst                      1.0
#
# [31 rows x 31 columns]

# %%
# Alternate method to get specific feature with desired correlation
for x,i in corr_matrix.iteritems():
    print('\n',pd.Series(i).where(pd.Series(i)>0.9).dropna())
# Out:
#  diagnosis    1.0
# Name: diagnosis, dtype: float64
#
#  radius_mean        1.000000
# perimeter_mean     0.997855
# area_mean          0.987357
# radius_worst       0.969539
# perimeter_worst    0.965137
# area_worst         0.941082
# Name: radius_mean, dtype: float64
#
#  texture_mean     1.000000
# texture_worst    0.912045
# Name: texture_mean, dtype: float64
#
#  radius_mean        0.997855
# perimeter_mean     1.000000
# area_mean          0.986507
# radius_worst       0.969476
# perimeter_worst    0.970387
# area_worst         0.941550
# Name: perimeter_mean, dtype: float64
#
#  radius_mean        0.987357
# perimeter_mean     0.986507
# area_mean          1.000000
# radius_worst       0.962746
# perimeter_worst    0.959120
# area_worst         0.959213
# Name: area_mean, dtype: float64
#
#  smoothness_mean    1.0
# Name: smoothness_mean, dtype: float64
#
#  compactness_mean    1.0
# Name: compactness_mean, dtype: float64
#
#  concavity_mean         1.000000
# concave points_mean    0.921391
# Name: concavity_mean, dtype: float64
#
#  concavity_mean          0.921391
# concave points_mean     1.000000
# concave points_worst    0.910155
# Name: concave points_mean, dtype: float64
#
#  symmetry_mean    1.0
# Name: symmetry_mean, dtype: float64
#
#  fractal_dimension_mean    1.0
# Name: fractal_dimension_mean, dtype: float64
#
#  radius_se       1.000000
# perimeter_se    0.972794
# area_se         0.951830
# Name: radius_se, dtype: float64
#
#  texture_se    1.0
# Name: texture_se, dtype: float64
#
#  radius_se       0.972794
# perimeter_se    1.000000
# area_se         0.937655
# Name: perimeter_se, dtype: float64
#
#  radius_se       0.951830
# perimeter_se    0.937655
# area_se         1.000000
# Name: area_se, dtype: float64
#
#  smoothness_se    1.0
# Name: smoothness_se, dtype: float64
#
#  compactness_se    1.0
# Name: compactness_se, dtype: float64
#
#  concavity_se    1.0
# Name: concavity_se, dtype: float64
#
#  concave points_se    1.0
# Name: concave points_se, dtype: float64
#
#  symmetry_se    1.0
# Name: symmetry_se, dtype: float64
#
#  fractal_dimension_se    1.0
# Name: fractal_dimension_se, dtype: float64
#
#  radius_mean        0.969539
# perimeter_mean     0.969476
# area_mean          0.962746
# radius_worst       1.000000
# perimeter_worst    0.993708
# area_worst         0.984015
# Name: radius_worst, dtype: float64
#
#  texture_mean     0.912045
# texture_worst    1.000000
# Name: texture_worst, dtype: float64
#
#  radius_mean        0.965137
# perimeter_mean     0.970387
# area_mean          0.959120
# radius_worst       0.993708
# perimeter_worst    1.000000
# area_worst         0.977578
# Name: perimeter_worst, dtype: float64
#
#  radius_mean        0.941082
# perimeter_mean     0.941550
# area_mean          0.959213
# radius_worst       0.984015
# perimeter_worst    0.977578
# area_worst         1.000000
# Name: area_worst, dtype: float64
#
#  smoothness_worst    1.0
# Name: smoothness_worst, dtype: float64
#
#  compactness_worst    1.0
# Name: compactness_worst, dtype: float64
#
#  concavity_worst    1.0
# Name: concavity_worst, dtype: float64
#
#  concave points_mean     0.910155
# concave points_worst    1.000000
# Name: concave points_worst, dtype: float64
#
#  symmetry_worst    1.0
# Name: symmetry_worst, dtype: float64
#
#  fractal_dimension_worst    1.0
# Name: fractal_dimension_worst, dtype: float64

# %%
# Decent correlation
corr_matrix.where((df.corr()<=0.9) & (df.corr()>0.5))
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                      NaN     0.730029           NaN        0.742636
# radius_mean               0.730029          NaN           NaN             NaN
# texture_mean                   NaN          NaN           NaN             NaN
# perimeter_mean            0.742636          NaN           NaN             NaN
# area_mean                 0.708984          NaN           NaN             NaN
# smoothness_mean                NaN          NaN           NaN             NaN
# compactness_mean          0.596534     0.506124           NaN        0.556936
# concavity_mean            0.696360     0.676764           NaN        0.716136
# concave points_mean       0.776614     0.822529           NaN        0.850977
# symmetry_mean                  NaN          NaN           NaN             NaN
# fractal_dimension_mean         NaN          NaN           NaN             NaN
# radius_se                 0.567134     0.679090           NaN        0.691765
# texture_se                     NaN          NaN           NaN             NaN
# perimeter_se              0.556141     0.674172           NaN        0.693135
# area_se                   0.548236     0.735864           NaN        0.744983
# smoothness_se                  NaN          NaN           NaN             NaN
# compactness_se                 NaN          NaN           NaN             NaN
# concavity_se                   NaN          NaN           NaN             NaN
# concave points_se              NaN          NaN           NaN             NaN
# symmetry_se                    NaN          NaN           NaN             NaN
# fractal_dimension_se           NaN          NaN           NaN             NaN
# radius_worst              0.776454          NaN           NaN             NaN
# texture_worst                  NaN          NaN           NaN             NaN
# perimeter_worst           0.782914          NaN           NaN             NaN
# area_worst                0.733825          NaN           NaN             NaN
# smoothness_worst               NaN          NaN           NaN             NaN
# compactness_worst         0.590998          NaN           NaN             NaN
# concavity_worst           0.659610     0.526911           NaN        0.563879
# concave points_worst      0.793566     0.744214           NaN        0.771241
# symmetry_worst                 NaN          NaN           NaN             NaN
# fractal_dimension_worst        NaN          NaN           NaN             NaN
#
#                          area_mean  smoothness_mean  compactness_mean  \
# diagnosis                 0.708984              NaN          0.596534
# radius_mean                    NaN              NaN          0.506124
# texture_mean                   NaN              NaN               NaN
# perimeter_mean                 NaN              NaN          0.556936
# area_mean                      NaN              NaN               NaN
# smoothness_mean                NaN              NaN          0.659123
# compactness_mean               NaN         0.659123               NaN
# concavity_mean            0.685983         0.521984          0.883121
# concave points_mean       0.823269         0.553695          0.831135
# symmetry_mean                  NaN         0.557775          0.602641
# fractal_dimension_mean         NaN         0.584792          0.565369
# radius_se                 0.732562              NaN               NaN
# texture_se                     NaN              NaN               NaN
# perimeter_se              0.726628              NaN          0.548905
# area_se                   0.800086              NaN               NaN
# smoothness_se                  NaN              NaN               NaN
# compactness_se                 NaN              NaN          0.738722
# concavity_se                   NaN              NaN          0.570517
# concave points_se              NaN              NaN          0.642262
# symmetry_se                    NaN              NaN               NaN
# fractal_dimension_se           NaN              NaN          0.507318
# radius_worst                   NaN              NaN          0.535315
# texture_worst                  NaN              NaN               NaN
# perimeter_worst                NaN              NaN          0.590210
# area_worst                     NaN              NaN          0.509604
# smoothness_worst               NaN         0.805324          0.565541
# compactness_worst              NaN              NaN          0.865809
# concavity_worst           0.512606              NaN          0.816275
# concave points_worst      0.722017         0.503053          0.815573
# symmetry_worst                 NaN              NaN          0.510223
# fractal_dimension_worst        NaN              NaN          0.687382
#
#                          concavity_mean  concave points_mean  symmetry_mean  \
# diagnosis                      0.696360             0.776614            NaN
# radius_mean                    0.676764             0.822529            NaN
# texture_mean                        NaN                  NaN            NaN
# perimeter_mean                 0.716136             0.850977            NaN
# area_mean                      0.685983             0.823269            NaN
# smoothness_mean                0.521984             0.553695       0.557775
# compactness_mean               0.883121             0.831135       0.602641
# concavity_mean                      NaN                  NaN       0.500667
# concave points_mean                 NaN                  NaN            NaN
# symmetry_mean                  0.500667                  NaN            NaN
# fractal_dimension_mean              NaN                  NaN            NaN
# radius_se                      0.631925             0.698050            NaN
# texture_se                          NaN                  NaN            NaN
# perimeter_se                   0.660391             0.710650            NaN
# area_se                        0.617427             0.690299            NaN
# smoothness_se                       NaN                  NaN            NaN
# compactness_se                 0.670279                  NaN            NaN
# concavity_se                   0.691270                  NaN            NaN
# concave points_se              0.683260             0.615634            NaN
# symmetry_se                         NaN                  NaN            NaN
# fractal_dimension_se                NaN                  NaN            NaN
# radius_worst                   0.688236             0.830318            NaN
# texture_worst                       NaN                  NaN            NaN
# perimeter_worst                0.729565             0.855923            NaN
# area_worst                     0.675987             0.809630            NaN
# smoothness_worst                    NaN                  NaN            NaN
# compactness_worst              0.754968             0.667454            NaN
# concavity_worst                0.884103             0.752399            NaN
# concave points_worst           0.861323                  NaN            NaN
# symmetry_worst                      NaN                  NaN       0.699826
# fractal_dimension_worst        0.514930                  NaN            NaN
#
#                                   ...             radius_worst  texture_worst  \
# diagnosis                         ...                 0.776454            NaN
# radius_mean                       ...                      NaN            NaN
# texture_mean                      ...                      NaN            NaN
# perimeter_mean                    ...                      NaN            NaN
# area_mean                         ...                      NaN            NaN
# smoothness_mean                   ...                      NaN            NaN
# compactness_mean                  ...                 0.535315            NaN
# concavity_mean                    ...                 0.688236            NaN
# concave points_mean               ...                 0.830318            NaN
# symmetry_mean                     ...                      NaN            NaN
# fractal_dimension_mean            ...                      NaN            NaN
# radius_se                         ...                 0.715065            NaN
# texture_se                        ...                      NaN            NaN
# perimeter_se                      ...                 0.697201            NaN
# area_se                           ...                 0.757373            NaN
# smoothness_se                     ...                      NaN            NaN
# compactness_se                    ...                      NaN            NaN
# concavity_se                      ...                      NaN            NaN
# concave points_se                 ...                      NaN            NaN
# symmetry_se                       ...                      NaN            NaN
# fractal_dimension_se              ...                      NaN            NaN
# radius_worst                      ...                      NaN            NaN
# texture_worst                     ...                      NaN            NaN
# perimeter_worst                   ...                      NaN            NaN
# area_worst                        ...                      NaN            NaN
# smoothness_worst                  ...                      NaN            NaN
# compactness_worst                 ...                      NaN            NaN
# concavity_worst                   ...                 0.573975            NaN
# concave points_worst              ...                 0.787424            NaN
# symmetry_worst                    ...                      NaN            NaN
# fractal_dimension_worst           ...                      NaN            NaN
#
#                          perimeter_worst  area_worst  smoothness_worst  \
# diagnosis                       0.782914    0.733825               NaN
# radius_mean                          NaN         NaN               NaN
# texture_mean                         NaN         NaN               NaN
# perimeter_mean                       NaN         NaN               NaN
# area_mean                            NaN         NaN               NaN
# smoothness_mean                      NaN         NaN          0.805324
# compactness_mean                0.590210    0.509604          0.565541
# concavity_mean                  0.729565    0.675987               NaN
# concave points_mean             0.855923    0.809630               NaN
# symmetry_mean                        NaN         NaN               NaN
# fractal_dimension_mean               NaN         NaN          0.504942
# radius_se                       0.719684    0.751548               NaN
# texture_se                           NaN         NaN               NaN
# perimeter_se                    0.721031    0.730713               NaN
# area_se                         0.761213    0.811408               NaN
# smoothness_se                        NaN         NaN               NaN
# compactness_se                       NaN         NaN               NaN
# concavity_se                         NaN         NaN               NaN
# concave points_se                    NaN         NaN               NaN
# symmetry_se                          NaN         NaN               NaN
# fractal_dimension_se                 NaN         NaN               NaN
# radius_worst                         NaN         NaN               NaN
# texture_worst                        NaN         NaN               NaN
# perimeter_worst                      NaN         NaN               NaN
# area_worst                           NaN         NaN               NaN
# smoothness_worst                     NaN         NaN               NaN
# compactness_worst               0.529408         NaN          0.568187
# concavity_worst                 0.618344    0.543331          0.518523
# concave points_worst            0.816322    0.747419          0.547691
# symmetry_worst                       NaN         NaN               NaN
# fractal_dimension_worst              NaN         NaN          0.617624
#
#                          compactness_worst  concavity_worst  \
# diagnosis                         0.590998         0.659610
# radius_mean                            NaN         0.526911
# texture_mean                           NaN              NaN
# perimeter_mean                         NaN         0.563879
# area_mean                              NaN         0.512606
# smoothness_mean                        NaN              NaN
# compactness_mean                  0.865809         0.816275
# concavity_mean                    0.754968         0.884103
# concave points_mean               0.667454         0.752399
# symmetry_mean                          NaN              NaN
# fractal_dimension_mean                 NaN              NaN
# radius_se                              NaN              NaN
# texture_se                             NaN              NaN
# perimeter_se                           NaN              NaN
# area_se                                NaN              NaN
# smoothness_se                          NaN              NaN
# compactness_se                    0.678780         0.639147
# concavity_se                           NaN         0.662564
# concave points_se                      NaN         0.549592
# symmetry_se                            NaN              NaN
# fractal_dimension_se                   NaN              NaN
# radius_worst                           NaN         0.573975
# texture_worst                          NaN              NaN
# perimeter_worst                   0.529408         0.618344
# area_worst                             NaN         0.543331
# smoothness_worst                  0.568187         0.518523
# compactness_worst                      NaN         0.892261
# concavity_worst                   0.892261              NaN
# concave points_worst              0.801080         0.855434
# symmetry_worst                    0.614441         0.532520
# fractal_dimension_worst           0.810455         0.686511
#
#                          concave points_worst  symmetry_worst  \
# diagnosis                            0.793566             NaN
# radius_mean                          0.744214             NaN
# texture_mean                              NaN             NaN
# perimeter_mean                       0.771241             NaN
# area_mean                            0.722017             NaN
# smoothness_mean                      0.503053             NaN
# compactness_mean                     0.815573        0.510223
# concavity_mean                       0.861323             NaN
# concave points_mean                       NaN             NaN
# symmetry_mean                             NaN        0.699826
# fractal_dimension_mean                    NaN             NaN
# radius_se                            0.531062             NaN
# texture_se                                NaN             NaN
# perimeter_se                         0.554897             NaN
# area_se                              0.538166             NaN
# smoothness_se                             NaN             NaN
# compactness_se                            NaN             NaN
# concavity_se                              NaN             NaN
# concave points_se                    0.602450             NaN
# symmetry_se                               NaN             NaN
# fractal_dimension_se                      NaN             NaN
# radius_worst                         0.787424             NaN
# texture_worst                             NaN             NaN
# perimeter_worst                      0.816322             NaN
# area_worst                           0.747419             NaN
# smoothness_worst                     0.547691             NaN
# compactness_worst                    0.801080        0.614441
# concavity_worst                      0.855434        0.532520
# concave points_worst                      NaN        0.502528
# symmetry_worst                       0.502528             NaN
# fractal_dimension_worst              0.511114        0.537848
#
#                          fractal_dimension_worst
# diagnosis                                    NaN
# radius_mean                                  NaN
# texture_mean                                 NaN
# perimeter_mean                               NaN
# area_mean                                    NaN
# smoothness_mean                              NaN
# compactness_mean                        0.687382
# concavity_mean                          0.514930
# concave points_mean                          NaN
# symmetry_mean                                NaN
# fractal_dimension_mean                  0.767297
# radius_se                                    NaN
# texture_se                                   NaN
# perimeter_se                                 NaN
# area_se                                      NaN
# smoothness_se                                NaN
# compactness_se                          0.590973
# concavity_se                                 NaN
# concave points_se                            NaN
# symmetry_se                                  NaN
# fractal_dimension_se                    0.591328
# radius_worst                                 NaN
# texture_worst                                NaN
# perimeter_worst                              NaN
# area_worst                                   NaN
# smoothness_worst                        0.617624
# compactness_worst                       0.810455
# concavity_worst                         0.686511
# concave points_worst                    0.511114
# symmetry_worst                          0.537848
# fractal_dimension_worst                      NaN
#
# [31 rows x 31 columns]

# %%
for x,i in corr_matrix.iteritems():
    print('\n',pd.Series(i).where((pd.Series(i)<=0.9) & (pd.Series(i)>0.5)).dropna())
# Out:
#  radius_mean             0.730029
# perimeter_mean          0.742636
# area_mean               0.708984
# compactness_mean        0.596534
# concavity_mean          0.696360
# concave points_mean     0.776614
# radius_se               0.567134
# perimeter_se            0.556141
# area_se                 0.548236
# radius_worst            0.776454
# perimeter_worst         0.782914
# area_worst              0.733825
# compactness_worst       0.590998
# concavity_worst         0.659610
# concave points_worst    0.793566
# Name: diagnosis, dtype: float64
#
#  diagnosis               0.730029
# compactness_mean        0.506124
# concavity_mean          0.676764
# concave points_mean     0.822529
# radius_se               0.679090
# perimeter_se            0.674172
# area_se                 0.735864
# concavity_worst         0.526911
# concave points_worst    0.744214
# Name: radius_mean, dtype: float64
#
#  Series([], Name: texture_mean, dtype: float64)
#
#  diagnosis               0.742636
# compactness_mean        0.556936
# concavity_mean          0.716136
# concave points_mean     0.850977
# radius_se               0.691765
# perimeter_se            0.693135
# area_se                 0.744983
# concavity_worst         0.563879
# concave points_worst    0.771241
# Name: perimeter_mean, dtype: float64
#
#  diagnosis               0.708984
# concavity_mean          0.685983
# concave points_mean     0.823269
# radius_se               0.732562
# perimeter_se            0.726628
# area_se                 0.800086
# concavity_worst         0.512606
# concave points_worst    0.722017
# Name: area_mean, dtype: float64
#
#  compactness_mean          0.659123
# concavity_mean            0.521984
# concave points_mean       0.553695
# symmetry_mean             0.557775
# fractal_dimension_mean    0.584792
# smoothness_worst          0.805324
# concave points_worst      0.503053
# Name: smoothness_mean, dtype: float64
#
#  diagnosis                  0.596534
# radius_mean                0.506124
# perimeter_mean             0.556936
# smoothness_mean            0.659123
# concavity_mean             0.883121
# concave points_mean        0.831135
# symmetry_mean              0.602641
# fractal_dimension_mean     0.565369
# perimeter_se               0.548905
# compactness_se             0.738722
# concavity_se               0.570517
# concave points_se          0.642262
# fractal_dimension_se       0.507318
# radius_worst               0.535315
# perimeter_worst            0.590210
# area_worst                 0.509604
# smoothness_worst           0.565541
# compactness_worst          0.865809
# concavity_worst            0.816275
# concave points_worst       0.815573
# symmetry_worst             0.510223
# fractal_dimension_worst    0.687382
# Name: compactness_mean, dtype: float64
#
#  diagnosis                  0.696360
# radius_mean                0.676764
# perimeter_mean             0.716136
# area_mean                  0.685983
# smoothness_mean            0.521984
# compactness_mean           0.883121
# symmetry_mean              0.500667
# radius_se                  0.631925
# perimeter_se               0.660391
# area_se                    0.617427
# compactness_se             0.670279
# concavity_se               0.691270
# concave points_se          0.683260
# radius_worst               0.688236
# perimeter_worst            0.729565
# area_worst                 0.675987
# compactness_worst          0.754968
# concavity_worst            0.884103
# concave points_worst       0.861323
# fractal_dimension_worst    0.514930
# Name: concavity_mean, dtype: float64
#
#  diagnosis            0.776614
# radius_mean          0.822529
# perimeter_mean       0.850977
# area_mean            0.823269
# smoothness_mean      0.553695
# compactness_mean     0.831135
# radius_se            0.698050
# perimeter_se         0.710650
# area_se              0.690299
# concave points_se    0.615634
# radius_worst         0.830318
# perimeter_worst      0.855923
# area_worst           0.809630
# compactness_worst    0.667454
# concavity_worst      0.752399
# Name: concave points_mean, dtype: float64
#
#  smoothness_mean     0.557775
# compactness_mean    0.602641
# concavity_mean      0.500667
# symmetry_worst      0.699826
# Name: symmetry_mean, dtype: float64
#
#  smoothness_mean            0.584792
# compactness_mean           0.565369
# compactness_se             0.559837
# fractal_dimension_se       0.688132
# smoothness_worst           0.504942
# fractal_dimension_worst    0.767297
# Name: fractal_dimension_mean, dtype: float64
#
#  diagnosis               0.567134
# radius_mean             0.679090
# perimeter_mean          0.691765
# area_mean               0.732562
# concavity_mean          0.631925
# concave points_mean     0.698050
# concave points_se       0.513346
# radius_worst            0.715065
# perimeter_worst         0.719684
# area_worst              0.751548
# concave points_worst    0.531062
# Name: radius_se, dtype: float64
#
#  Series([], Name: texture_se, dtype: float64)
#
#  diagnosis               0.556141
# radius_mean             0.674172
# perimeter_mean          0.693135
# area_mean               0.726628
# compactness_mean        0.548905
# concavity_mean          0.660391
# concave points_mean     0.710650
# concave points_se       0.556264
# radius_worst            0.697201
# perimeter_worst         0.721031
# area_worst              0.730713
# concave points_worst    0.554897
# Name: perimeter_se, dtype: float64
#
#  diagnosis               0.548236
# radius_mean             0.735864
# perimeter_mean          0.744983
# area_mean               0.800086
# concavity_mean          0.617427
# concave points_mean     0.690299
# radius_worst            0.757373
# perimeter_worst         0.761213
# area_worst              0.811408
# concave points_worst    0.538166
# Name: area_se, dtype: float64
#
#  Series([], Name: smoothness_se, dtype: float64)
#
#  compactness_mean           0.738722
# concavity_mean             0.670279
# fractal_dimension_mean     0.559837
# concavity_se               0.801268
# concave points_se          0.744083
# fractal_dimension_se       0.803269
# compactness_worst          0.678780
# concavity_worst            0.639147
# fractal_dimension_worst    0.590973
# Name: compactness_se, dtype: float64
#
#  compactness_mean        0.570517
# concavity_mean          0.691270
# compactness_se          0.801268
# concave points_se       0.771804
# fractal_dimension_se    0.727372
# concavity_worst         0.662564
# Name: concavity_se, dtype: float64
#
#  compactness_mean        0.642262
# concavity_mean          0.683260
# concave points_mean     0.615634
# radius_se               0.513346
# perimeter_se            0.556264
# compactness_se          0.744083
# concavity_se            0.771804
# fractal_dimension_se    0.611044
# concavity_worst         0.549592
# concave points_worst    0.602450
# Name: concave points_se, dtype: float64
#
#  Series([], Name: symmetry_se, dtype: float64)
#
#  compactness_mean           0.507318
# fractal_dimension_mean     0.688132
# compactness_se             0.803269
# concavity_se               0.727372
# concave points_se          0.611044
# fractal_dimension_worst    0.591328
# Name: fractal_dimension_se, dtype: float64
#
#  diagnosis               0.776454
# compactness_mean        0.535315
# concavity_mean          0.688236
# concave points_mean     0.830318
# radius_se               0.715065
# perimeter_se            0.697201
# area_se                 0.757373
# concavity_worst         0.573975
# concave points_worst    0.787424
# Name: radius_worst, dtype: float64
#
#  Series([], Name: texture_worst, dtype: float64)
#
#  diagnosis               0.782914
# compactness_mean        0.590210
# concavity_mean          0.729565
# concave points_mean     0.855923
# radius_se               0.719684
# perimeter_se            0.721031
# area_se                 0.761213
# compactness_worst       0.529408
# concavity_worst         0.618344
# concave points_worst    0.816322
# Name: perimeter_worst, dtype: float64
#
#  diagnosis               0.733825
# compactness_mean        0.509604
# concavity_mean          0.675987
# concave points_mean     0.809630
# radius_se               0.751548
# perimeter_se            0.730713
# area_se                 0.811408
# concavity_worst         0.543331
# concave points_worst    0.747419
# Name: area_worst, dtype: float64
#
#  smoothness_mean            0.805324
# compactness_mean           0.565541
# fractal_dimension_mean     0.504942
# compactness_worst          0.568187
# concavity_worst            0.518523
# concave points_worst       0.547691
# fractal_dimension_worst    0.617624
# Name: smoothness_worst, dtype: float64
#
#  diagnosis                  0.590998
# compactness_mean           0.865809
# concavity_mean             0.754968
# concave points_mean        0.667454
# compactness_se             0.678780
# perimeter_worst            0.529408
# smoothness_worst           0.568187
# concavity_worst            0.892261
# concave points_worst       0.801080
# symmetry_worst             0.614441
# fractal_dimension_worst    0.810455
# Name: compactness_worst, dtype: float64
#
#  diagnosis                  0.659610
# radius_mean                0.526911
# perimeter_mean             0.563879
# area_mean                  0.512606
# compactness_mean           0.816275
# concavity_mean             0.884103
# concave points_mean        0.752399
# compactness_se             0.639147
# concavity_se               0.662564
# concave points_se          0.549592
# radius_worst               0.573975
# perimeter_worst            0.618344
# area_worst                 0.543331
# smoothness_worst           0.518523
# compactness_worst          0.892261
# concave points_worst       0.855434
# symmetry_worst             0.532520
# fractal_dimension_worst    0.686511
# Name: concavity_worst, dtype: float64
#
#  diagnosis                  0.793566
# radius_mean                0.744214
# perimeter_mean             0.771241
# area_mean                  0.722017
# smoothness_mean            0.503053
# compactness_mean           0.815573
# concavity_mean             0.861323
# radius_se                  0.531062
# perimeter_se               0.554897
# area_se                    0.538166
# concave points_se          0.602450
# radius_worst               0.787424
# perimeter_worst            0.816322
# area_worst                 0.747419
# smoothness_worst           0.547691
# compactness_worst          0.801080
# concavity_worst            0.855434
# symmetry_worst             0.502528
# fractal_dimension_worst    0.511114
# Name: concave points_worst, dtype: float64
#
#  compactness_mean           0.510223
# symmetry_mean              0.699826
# compactness_worst          0.614441
# concavity_worst            0.532520
# concave points_worst       0.502528
# fractal_dimension_worst    0.537848
# Name: symmetry_worst, dtype: float64
#
#  compactness_mean          0.687382
# concavity_mean            0.514930
# fractal_dimension_mean    0.767297
# compactness_se            0.590973
# fractal_dimension_se      0.591328
# smoothness_worst          0.617624
# compactness_worst         0.810455
# concavity_worst           0.686511
# concave points_worst      0.511114
# symmetry_worst            0.537848
# Name: fractal_dimension_worst, dtype: float64

# %%
# Weekly correlated features
corr_matrix.where((df.corr()<=0.5) & (df.corr()>0))
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                      NaN          NaN      0.415185             NaN
# radius_mean                    NaN          NaN      0.323782             NaN
# texture_mean              0.415185     0.323782           NaN        0.329533
# perimeter_mean                 NaN          NaN      0.329533             NaN
# area_mean                      NaN          NaN      0.321086             NaN
# smoothness_mean           0.358560     0.170581           NaN        0.207278
# compactness_mean               NaN          NaN      0.236702             NaN
# concavity_mean                 NaN          NaN      0.302418             NaN
# concave points_mean            NaN          NaN      0.293464             NaN
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean         NaN          NaN           NaN             NaN
# radius_se                      NaN          NaN      0.275869             NaN
# texture_se                     NaN          NaN      0.386358             NaN
# perimeter_se                   NaN          NaN      0.281673             NaN
# area_se                        NaN          NaN      0.259845             NaN
# smoothness_se                  NaN          NaN      0.006614             NaN
# compactness_se            0.292999     0.206000      0.191975        0.250744
# concavity_se              0.253730     0.194204      0.143293        0.228082
# concave points_se         0.408042     0.376169      0.163851        0.407217
# symmetry_se                    NaN          NaN      0.009127             NaN
# fractal_dimension_se      0.077972          NaN      0.054458             NaN
# radius_worst                   NaN          NaN      0.352573             NaN
# texture_worst             0.456903     0.297008           NaN        0.303038
# perimeter_worst                NaN          NaN      0.358040             NaN
# area_worst                     NaN          NaN      0.343546             NaN
# smoothness_worst          0.421465     0.119616      0.077503        0.150549
# compactness_worst              NaN     0.413463      0.277830        0.455774
# concavity_worst                NaN          NaN      0.301025             NaN
# concave points_worst           NaN          NaN      0.295316             NaN
# symmetry_worst            0.416294     0.163953      0.105008        0.189115
# fractal_dimension_worst   0.323872     0.007066      0.119205        0.051019
#
#                          area_mean  smoothness_mean  compactness_mean  \
# diagnosis                      NaN         0.358560               NaN
# radius_mean                    NaN         0.170581               NaN
# texture_mean              0.321086              NaN          0.236702
# perimeter_mean                 NaN         0.207278               NaN
# area_mean                      NaN         0.177028          0.498502
# smoothness_mean           0.177028              NaN               NaN
# compactness_mean          0.498502              NaN               NaN
# concavity_mean                 NaN              NaN               NaN
# concave points_mean            NaN              NaN               NaN
# symmetry_mean             0.151293              NaN               NaN
# fractal_dimension_mean         NaN              NaN               NaN
# radius_se                      NaN         0.301467          0.497473
# texture_se                     NaN         0.068406          0.046205
# perimeter_se                   NaN         0.296092               NaN
# area_se                        NaN         0.246552          0.455653
# smoothness_se                  NaN         0.332375          0.135299
# compactness_se            0.212583         0.318943               NaN
# concavity_se              0.207660         0.248396               NaN
# concave points_se         0.372320         0.380676               NaN
# symmetry_se                    NaN         0.200774          0.229977
# fractal_dimension_se           NaN         0.283607               NaN
# radius_worst                   NaN         0.213120               NaN
# texture_worst             0.287489         0.036072          0.248133
# perimeter_worst                NaN         0.238853               NaN
# area_worst                     NaN         0.206718               NaN
# smoothness_worst          0.123523              NaN               NaN
# compactness_worst         0.390410         0.472468               NaN
# concavity_worst                NaN         0.434926               NaN
# concave points_worst           NaN              NaN               NaN
# symmetry_worst            0.143570         0.394309               NaN
# fractal_dimension_worst   0.003738         0.499316               NaN
#
#                          concavity_mean  concave points_mean  symmetry_mean  \
# diagnosis                           NaN                  NaN       0.330499
# radius_mean                         NaN                  NaN       0.147741
# texture_mean                   0.302418             0.293464       0.071401
# perimeter_mean                      NaN                  NaN       0.183027
# area_mean                           NaN                  NaN       0.151293
# smoothness_mean                     NaN                  NaN            NaN
# compactness_mean                    NaN                  NaN            NaN
# concavity_mean                      NaN                  NaN            NaN
# concave points_mean                 NaN                  NaN       0.462497
# symmetry_mean                       NaN             0.462497            NaN
# fractal_dimension_mean         0.336783             0.166917       0.479921
# radius_se                           NaN                  NaN       0.303379
# texture_se                     0.076218             0.021480       0.128053
# perimeter_se                        NaN                  NaN       0.313893
# area_se                             NaN                  NaN       0.223970
# smoothness_se                  0.098564             0.027653       0.187321
# compactness_se                      NaN             0.490424       0.421659
# concavity_se                        NaN             0.439167       0.342627
# concave points_se                   NaN                  NaN       0.393298
# symmetry_se                    0.178009             0.095351       0.449137
# fractal_dimension_se           0.449301             0.257584       0.331786
# radius_worst                        NaN                  NaN       0.185728
# texture_worst                  0.299879             0.292752       0.090651
# perimeter_worst                     NaN                  NaN       0.219169
# area_worst                          NaN                  NaN       0.177193
# smoothness_worst               0.448822             0.452753       0.426675
# compactness_worst                   NaN                  NaN       0.473200
# concavity_worst                     NaN                  NaN       0.433721
# concave points_worst                NaN                  NaN       0.430297
# symmetry_worst                 0.409464             0.375744            NaN
# fractal_dimension_worst             NaN             0.368661       0.438413
#
#                                   ...             radius_worst  texture_worst  \
# diagnosis                         ...                      NaN       0.456903
# radius_mean                       ...                      NaN       0.297008
# texture_mean                      ...                 0.352573            NaN
# perimeter_mean                    ...                      NaN       0.303038
# area_mean                         ...                      NaN       0.287489
# smoothness_mean                   ...                 0.213120       0.036072
# compactness_mean                  ...                      NaN       0.248133
# concavity_mean                    ...                      NaN       0.299879
# concave points_mean               ...                      NaN       0.292752
# symmetry_mean                     ...                 0.185728       0.090651
# fractal_dimension_mean            ...                      NaN            NaN
# radius_se                         ...                      NaN       0.194799
# texture_se                        ...                      NaN       0.409003
# perimeter_se                      ...                      NaN       0.200371
# area_se                           ...                      NaN       0.196497
# smoothness_se                     ...                      NaN            NaN
# compactness_se                    ...                 0.204607       0.143003
# concavity_se                      ...                 0.186904       0.100241
# concave points_se                 ...                 0.358127       0.086741
# symmetry_se                       ...                      NaN            NaN
# fractal_dimension_se              ...                      NaN            NaN
# radius_worst                      ...                      NaN       0.359921
# texture_worst                     ...                 0.359921            NaN
# perimeter_worst                   ...                      NaN       0.365098
# area_worst                        ...                      NaN       0.345842
# smoothness_worst                  ...                 0.216574       0.225429
# compactness_worst                 ...                 0.475820       0.360832
# concavity_worst                   ...                      NaN       0.368366
# concave points_worst              ...                      NaN       0.359755
# symmetry_worst                    ...                 0.243529       0.233027
# fractal_dimension_worst           ...                 0.093492       0.219122
#
#                          perimeter_worst  area_worst  smoothness_worst  \
# diagnosis                            NaN         NaN          0.421465
# radius_mean                          NaN         NaN          0.119616
# texture_mean                    0.358040    0.343546          0.077503
# perimeter_mean                       NaN         NaN          0.150549
# area_mean                            NaN         NaN          0.123523
# smoothness_mean                 0.238853    0.206718               NaN
# compactness_mean                     NaN         NaN               NaN
# concavity_mean                       NaN         NaN          0.448822
# concave points_mean                  NaN         NaN          0.452753
# symmetry_mean                   0.219169    0.177193          0.426675
# fractal_dimension_mean               NaN         NaN               NaN
# radius_se                            NaN         NaN          0.141919
# texture_se                           NaN         NaN               NaN
# perimeter_se                         NaN         NaN          0.130054
# area_se                              NaN         NaN          0.125389
# smoothness_se                        NaN         NaN          0.314457
# compactness_se                  0.260516    0.199371          0.227394
# concavity_se                    0.226680    0.188353          0.168481
# concave points_se               0.394999    0.342271          0.215351
# symmetry_se                          NaN         NaN               NaN
# fractal_dimension_se                 NaN         NaN          0.170568
# radius_worst                         NaN         NaN          0.216574
# texture_worst                   0.365098    0.345842          0.225429
# perimeter_worst                      NaN         NaN          0.236775
# area_worst                           NaN         NaN          0.209145
# smoothness_worst                0.236775    0.209145               NaN
# compactness_worst                    NaN    0.438296               NaN
# concavity_worst                      NaN         NaN               NaN
# concave points_worst                 NaN         NaN               NaN
# symmetry_worst                  0.269493    0.209146          0.493838
# fractal_dimension_worst         0.138957    0.079647               NaN
#
#                          compactness_worst  concavity_worst  \
# diagnosis                              NaN              NaN
# radius_mean                       0.413463              NaN
# texture_mean                      0.277830         0.301025
# perimeter_mean                    0.455774              NaN
# area_mean                         0.390410              NaN
# smoothness_mean                   0.472468         0.434926
# compactness_mean                       NaN              NaN
# concavity_mean                         NaN              NaN
# concave points_mean                    NaN              NaN
# symmetry_mean                     0.473200         0.433721
# fractal_dimension_mean            0.458798         0.346234
# radius_se                         0.287103         0.380585
# texture_se                             NaN              NaN
# perimeter_se                      0.341919         0.418899
# area_se                           0.283257         0.385100
# smoothness_se                          NaN              NaN
# compactness_se                         NaN              NaN
# concavity_se                      0.484858              NaN
# concave points_se                 0.452888              NaN
# symmetry_se                       0.060255         0.037119
# fractal_dimension_se              0.390159         0.379975
# radius_worst                      0.475820              NaN
# texture_worst                     0.360832         0.368366
# perimeter_worst                        NaN              NaN
# area_worst                        0.438296              NaN
# smoothness_worst                       NaN              NaN
# compactness_worst                      NaN              NaN
# concavity_worst                        NaN              NaN
# concave points_worst                   NaN              NaN
# symmetry_worst                         NaN              NaN
# fractal_dimension_worst                NaN              NaN
#
#                          concave points_worst  symmetry_worst  \
# diagnosis                                 NaN        0.416294
# radius_mean                               NaN        0.163953
# texture_mean                         0.295316        0.105008
# perimeter_mean                            NaN        0.189115
# area_mean                                 NaN        0.143570
# smoothness_mean                           NaN        0.394309
# compactness_mean                          NaN             NaN
# concavity_mean                            NaN        0.409464
# concave points_mean                       NaN        0.375744
# symmetry_mean                        0.430297             NaN
# fractal_dimension_mean               0.175325        0.334019
# radius_se                                 NaN        0.094543
# texture_se                                NaN             NaN
# perimeter_se                              NaN        0.109930
# area_se                                   NaN        0.074126
# smoothness_se                             NaN             NaN
# compactness_se                       0.483208        0.277878
# concavity_se                         0.440472        0.197788
# concave points_se                         NaN        0.143116
# symmetry_se                               NaN        0.389402
# fractal_dimension_se                 0.215204        0.111094
# radius_worst                              NaN        0.243529
# texture_worst                        0.359755        0.233027
# perimeter_worst                           NaN        0.269493
# area_worst                                NaN        0.209146
# smoothness_worst                          NaN        0.493838
# compactness_worst                         NaN             NaN
# concavity_worst                           NaN             NaN
# concave points_worst                      NaN             NaN
# symmetry_worst                            NaN             NaN
# fractal_dimension_worst                   NaN             NaN
#
#                          fractal_dimension_worst
# diagnosis                               0.323872
# radius_mean                             0.007066
# texture_mean                            0.119205
# perimeter_mean                          0.051019
# area_mean                               0.003738
# smoothness_mean                         0.499316
# compactness_mean                             NaN
# concavity_mean                               NaN
# concave points_mean                     0.368661
# symmetry_mean                           0.438413
# fractal_dimension_mean                       NaN
# radius_se                               0.049559
# texture_se                                   NaN
# perimeter_se                            0.085433
# area_se                                 0.017539
# smoothness_se                           0.101480
# compactness_se                               NaN
# concavity_se                            0.439329
# concave points_se                       0.310655
# symmetry_se                             0.078079
# fractal_dimension_se                         NaN
# radius_worst                            0.093492
# texture_worst                           0.219122
# perimeter_worst                         0.138957
# area_worst                              0.079647
# smoothness_worst                             NaN
# compactness_worst                            NaN
# concavity_worst                              NaN
# concave points_worst                         NaN
# symmetry_worst                               NaN
# fractal_dimension_worst                      NaN
#
# [31 rows x 31 columns]

# %%
for x,i in corr_matrix.iteritems():
    print('\n',pd.Series(i).where((pd.Series(i)<=0.5) & (pd.Series(i)>0)).dropna())
# Out:
#  texture_mean               0.415185
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# compactness_se             0.292999
# concavity_se               0.253730
# concave points_se          0.408042
# fractal_dimension_se       0.077972
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# fractal_dimension_worst    0.323872
# Name: diagnosis, dtype: float64
#
#  texture_mean               0.323782
# smoothness_mean            0.170581
# symmetry_mean              0.147741
# compactness_se             0.206000
# concavity_se               0.194204
# concave points_se          0.376169
# texture_worst              0.297008
# smoothness_worst           0.119616
# compactness_worst          0.413463
# symmetry_worst             0.163953
# fractal_dimension_worst    0.007066
# Name: radius_mean, dtype: float64
#
#  diagnosis                  0.415185
# radius_mean                0.323782
# perimeter_mean             0.329533
# area_mean                  0.321086
# compactness_mean           0.236702
# concavity_mean             0.302418
# concave points_mean        0.293464
# symmetry_mean              0.071401
# radius_se                  0.275869
# texture_se                 0.386358
# perimeter_se               0.281673
# area_se                    0.259845
# smoothness_se              0.006614
# compactness_se             0.191975
# concavity_se               0.143293
# concave points_se          0.163851
# symmetry_se                0.009127
# fractal_dimension_se       0.054458
# radius_worst               0.352573
# perimeter_worst            0.358040
# area_worst                 0.343546
# smoothness_worst           0.077503
# compactness_worst          0.277830
# concavity_worst            0.301025
# concave points_worst       0.295316
# symmetry_worst             0.105008
# fractal_dimension_worst    0.119205
# Name: texture_mean, dtype: float64
#
#  texture_mean               0.329533
# smoothness_mean            0.207278
# symmetry_mean              0.183027
# compactness_se             0.250744
# concavity_se               0.228082
# concave points_se          0.407217
# texture_worst              0.303038
# smoothness_worst           0.150549
# compactness_worst          0.455774
# symmetry_worst             0.189115
# fractal_dimension_worst    0.051019
# Name: perimeter_mean, dtype: float64
#
#  texture_mean               0.321086
# smoothness_mean            0.177028
# compactness_mean           0.498502
# symmetry_mean              0.151293
# compactness_se             0.212583
# concavity_se               0.207660
# concave points_se          0.372320
# texture_worst              0.287489
# smoothness_worst           0.123523
# compactness_worst          0.390410
# symmetry_worst             0.143570
# fractal_dimension_worst    0.003738
# Name: area_mean, dtype: float64
#
#  diagnosis                  0.358560
# radius_mean                0.170581
# perimeter_mean             0.207278
# area_mean                  0.177028
# radius_se                  0.301467
# texture_se                 0.068406
# perimeter_se               0.296092
# area_se                    0.246552
# smoothness_se              0.332375
# compactness_se             0.318943
# concavity_se               0.248396
# concave points_se          0.380676
# symmetry_se                0.200774
# fractal_dimension_se       0.283607
# radius_worst               0.213120
# texture_worst              0.036072
# perimeter_worst            0.238853
# area_worst                 0.206718
# compactness_worst          0.472468
# concavity_worst            0.434926
# symmetry_worst             0.394309
# fractal_dimension_worst    0.499316
# Name: smoothness_mean, dtype: float64
#
#  texture_mean     0.236702
# area_mean        0.498502
# radius_se        0.497473
# texture_se       0.046205
# area_se          0.455653
# smoothness_se    0.135299
# symmetry_se      0.229977
# texture_worst    0.248133
# Name: compactness_mean, dtype: float64
#
#  texture_mean              0.302418
# fractal_dimension_mean    0.336783
# texture_se                0.076218
# smoothness_se             0.098564
# symmetry_se               0.178009
# fractal_dimension_se      0.449301
# texture_worst             0.299879
# smoothness_worst          0.448822
# symmetry_worst            0.409464
# Name: concavity_mean, dtype: float64
#
#  texture_mean               0.293464
# symmetry_mean              0.462497
# fractal_dimension_mean     0.166917
# texture_se                 0.021480
# smoothness_se              0.027653
# compactness_se             0.490424
# concavity_se               0.439167
# symmetry_se                0.095351
# fractal_dimension_se       0.257584
# texture_worst              0.292752
# smoothness_worst           0.452753
# symmetry_worst             0.375744
# fractal_dimension_worst    0.368661
# Name: concave points_mean, dtype: float64
#
#  diagnosis                  0.330499
# radius_mean                0.147741
# texture_mean               0.071401
# perimeter_mean             0.183027
# area_mean                  0.151293
# concave points_mean        0.462497
# fractal_dimension_mean     0.479921
# radius_se                  0.303379
# texture_se                 0.128053
# perimeter_se               0.313893
# area_se                    0.223970
# smoothness_se              0.187321
# compactness_se             0.421659
# concavity_se               0.342627
# concave points_se          0.393298
# symmetry_se                0.449137
# fractal_dimension_se       0.331786
# radius_worst               0.185728
# texture_worst              0.090651
# perimeter_worst            0.219169
# area_worst                 0.177193
# smoothness_worst           0.426675
# compactness_worst          0.473200
# concavity_worst            0.433721
# concave points_worst       0.430297
# fractal_dimension_worst    0.438413
# Name: symmetry_mean, dtype: float64
#
#  concavity_mean          0.336783
# concave points_mean     0.166917
# symmetry_mean           0.479921
# radius_se               0.000111
# texture_se              0.164174
# perimeter_se            0.039830
# smoothness_se           0.401964
# concavity_se            0.446630
# concave points_se       0.341198
# symmetry_se             0.345007
# compactness_worst       0.458798
# concavity_worst         0.346234
# concave points_worst    0.175325
# symmetry_worst          0.334019
# Name: fractal_dimension_mean, dtype: float64
#
#  texture_mean               0.275869
# smoothness_mean            0.301467
# compactness_mean           0.497473
# symmetry_mean              0.303379
# fractal_dimension_mean     0.000111
# texture_se                 0.213247
# smoothness_se              0.164514
# compactness_se             0.356065
# concavity_se               0.332358
# symmetry_se                0.240567
# fractal_dimension_se       0.227754
# texture_worst              0.194799
# smoothness_worst           0.141919
# compactness_worst          0.287103
# concavity_worst            0.380585
# symmetry_worst             0.094543
# fractal_dimension_worst    0.049559
# Name: radius_se, dtype: float64
#
#  texture_mean              0.386358
# smoothness_mean           0.068406
# compactness_mean          0.046205
# concavity_mean            0.076218
# concave points_mean       0.021480
# symmetry_mean             0.128053
# fractal_dimension_mean    0.164174
# radius_se                 0.213247
# perimeter_se              0.223171
# area_se                   0.111567
# smoothness_se             0.397243
# compactness_se            0.231700
# concavity_se              0.194998
# concave points_se         0.230283
# symmetry_se               0.411621
# fractal_dimension_se      0.279723
# texture_worst             0.409003
# Name: texture_se, dtype: float64
#
#  texture_mean               0.281673
# smoothness_mean            0.296092
# symmetry_mean              0.313893
# fractal_dimension_mean     0.039830
# texture_se                 0.223171
# smoothness_se              0.151075
# compactness_se             0.416322
# concavity_se               0.362482
# symmetry_se                0.266487
# fractal_dimension_se       0.244143
# texture_worst              0.200371
# smoothness_worst           0.130054
# compactness_worst          0.341919
# concavity_worst            0.418899
# symmetry_worst             0.109930
# fractal_dimension_worst    0.085433
# Name: perimeter_se, dtype: float64
#
#  texture_mean               0.259845
# smoothness_mean            0.246552
# compactness_mean           0.455653
# symmetry_mean              0.223970
# texture_se                 0.111567
# smoothness_se              0.075150
# compactness_se             0.284840
# concavity_se               0.270895
# concave points_se          0.415730
# symmetry_se                0.134109
# fractal_dimension_se       0.127071
# texture_worst              0.196497
# smoothness_worst           0.125389
# compactness_worst          0.283257
# concavity_worst            0.385100
# symmetry_worst             0.074126
# fractal_dimension_worst    0.017539
# Name: area_se, dtype: float64
#
#  texture_mean               0.006614
# smoothness_mean            0.332375
# compactness_mean           0.135299
# concavity_mean             0.098564
# concave points_mean        0.027653
# symmetry_mean              0.187321
# fractal_dimension_mean     0.401964
# radius_se                  0.164514
# texture_se                 0.397243
# perimeter_se               0.151075
# area_se                    0.075150
# compactness_se             0.336696
# concavity_se               0.268685
# concave points_se          0.328429
# symmetry_se                0.413506
# fractal_dimension_se       0.427374
# smoothness_worst           0.314457
# fractal_dimension_worst    0.101480
# Name: smoothness_se, dtype: float64
#
#  diagnosis               0.292999
# radius_mean             0.206000
# texture_mean            0.191975
# perimeter_mean          0.250744
# area_mean               0.212583
# smoothness_mean         0.318943
# concave points_mean     0.490424
# symmetry_mean           0.421659
# radius_se               0.356065
# texture_se              0.231700
# perimeter_se            0.416322
# area_se                 0.284840
# smoothness_se           0.336696
# symmetry_se             0.394713
# radius_worst            0.204607
# texture_worst           0.143003
# perimeter_worst         0.260516
# area_worst              0.199371
# smoothness_worst        0.227394
# concave points_worst    0.483208
# symmetry_worst          0.277878
# Name: compactness_se, dtype: float64
#
#  diagnosis                  0.253730
# radius_mean                0.194204
# texture_mean               0.143293
# perimeter_mean             0.228082
# area_mean                  0.207660
# smoothness_mean            0.248396
# concave points_mean        0.439167
# symmetry_mean              0.342627
# fractal_dimension_mean     0.446630
# radius_se                  0.332358
# texture_se                 0.194998
# perimeter_se               0.362482
# area_se                    0.270895
# smoothness_se              0.268685
# symmetry_se                0.309429
# radius_worst               0.186904
# texture_worst              0.100241
# perimeter_worst            0.226680
# area_worst                 0.188353
# smoothness_worst           0.168481
# compactness_worst          0.484858
# concave points_worst       0.440472
# symmetry_worst             0.197788
# fractal_dimension_worst    0.439329
# Name: concavity_se, dtype: float64
#
#  diagnosis                  0.408042
# radius_mean                0.376169
# texture_mean               0.163851
# perimeter_mean             0.407217
# area_mean                  0.372320
# smoothness_mean            0.380676
# symmetry_mean              0.393298
# fractal_dimension_mean     0.341198
# texture_se                 0.230283
# area_se                    0.415730
# smoothness_se              0.328429
# symmetry_se                0.312780
# radius_worst               0.358127
# texture_worst              0.086741
# perimeter_worst            0.394999
# area_worst                 0.342271
# smoothness_worst           0.215351
# compactness_worst          0.452888
# symmetry_worst             0.143116
# fractal_dimension_worst    0.310655
# Name: concave points_se, dtype: float64
#
#  texture_mean               0.009127
# smoothness_mean            0.200774
# compactness_mean           0.229977
# concavity_mean             0.178009
# concave points_mean        0.095351
# symmetry_mean              0.449137
# fractal_dimension_mean     0.345007
# radius_se                  0.240567
# texture_se                 0.411621
# perimeter_se               0.266487
# area_se                    0.134109
# smoothness_se              0.413506
# compactness_se             0.394713
# concavity_se               0.309429
# concave points_se          0.312780
# fractal_dimension_se       0.369078
# compactness_worst          0.060255
# concavity_worst            0.037119
# symmetry_worst             0.389402
# fractal_dimension_worst    0.078079
# Name: symmetry_se, dtype: float64
#
#  diagnosis               0.077972
# texture_mean            0.054458
# smoothness_mean         0.283607
# concavity_mean          0.449301
# concave points_mean     0.257584
# symmetry_mean           0.331786
# radius_se               0.227754
# texture_se              0.279723
# perimeter_se            0.244143
# area_se                 0.127071
# smoothness_se           0.427374
# symmetry_se             0.369078
# smoothness_worst        0.170568
# compactness_worst       0.390159
# concavity_worst         0.379975
# concave points_worst    0.215204
# symmetry_worst          0.111094
# Name: fractal_dimension_se, dtype: float64
#
#  texture_mean               0.352573
# smoothness_mean            0.213120
# symmetry_mean              0.185728
# compactness_se             0.204607
# concavity_se               0.186904
# concave points_se          0.358127
# texture_worst              0.359921
# smoothness_worst           0.216574
# compactness_worst          0.475820
# symmetry_worst             0.243529
# fractal_dimension_worst    0.093492
# Name: radius_worst, dtype: float64
#
#  diagnosis                  0.456903
# radius_mean                0.297008
# perimeter_mean             0.303038
# area_mean                  0.287489
# smoothness_mean            0.036072
# compactness_mean           0.248133
# concavity_mean             0.299879
# concave points_mean        0.292752
# symmetry_mean              0.090651
# radius_se                  0.194799
# texture_se                 0.409003
# perimeter_se               0.200371
# area_se                    0.196497
# compactness_se             0.143003
# concavity_se               0.100241
# concave points_se          0.086741
# radius_worst               0.359921
# perimeter_worst            0.365098
# area_worst                 0.345842
# smoothness_worst           0.225429
# compactness_worst          0.360832
# concavity_worst            0.368366
# concave points_worst       0.359755
# symmetry_worst             0.233027
# fractal_dimension_worst    0.219122
# Name: texture_worst, dtype: float64
#
#  texture_mean               0.358040
# smoothness_mean            0.238853
# symmetry_mean              0.219169
# compactness_se             0.260516
# concavity_se               0.226680
# concave points_se          0.394999
# texture_worst              0.365098
# smoothness_worst           0.236775
# symmetry_worst             0.269493
# fractal_dimension_worst    0.138957
# Name: perimeter_worst, dtype: float64
#
#  texture_mean               0.343546
# smoothness_mean            0.206718
# symmetry_mean              0.177193
# compactness_se             0.199371
# concavity_se               0.188353
# concave points_se          0.342271
# texture_worst              0.345842
# smoothness_worst           0.209145
# compactness_worst          0.438296
# symmetry_worst             0.209146
# fractal_dimension_worst    0.079647
# Name: area_worst, dtype: float64
#
#  diagnosis               0.421465
# radius_mean             0.119616
# texture_mean            0.077503
# perimeter_mean          0.150549
# area_mean               0.123523
# concavity_mean          0.448822
# concave points_mean     0.452753
# symmetry_mean           0.426675
# radius_se               0.141919
# perimeter_se            0.130054
# area_se                 0.125389
# smoothness_se           0.314457
# compactness_se          0.227394
# concavity_se            0.168481
# concave points_se       0.215351
# fractal_dimension_se    0.170568
# radius_worst            0.216574
# texture_worst           0.225429
# perimeter_worst         0.236775
# area_worst              0.209145
# symmetry_worst          0.493838
# Name: smoothness_worst, dtype: float64
#
#  radius_mean               0.413463
# texture_mean              0.277830
# perimeter_mean            0.455774
# area_mean                 0.390410
# smoothness_mean           0.472468
# symmetry_mean             0.473200
# fractal_dimension_mean    0.458798
# radius_se                 0.287103
# perimeter_se              0.341919
# area_se                   0.283257
# concavity_se              0.484858
# concave points_se         0.452888
# symmetry_se               0.060255
# fractal_dimension_se      0.390159
# radius_worst              0.475820
# texture_worst             0.360832
# area_worst                0.438296
# Name: compactness_worst, dtype: float64
#
#  texture_mean              0.301025
# smoothness_mean           0.434926
# symmetry_mean             0.433721
# fractal_dimension_mean    0.346234
# radius_se                 0.380585
# perimeter_se              0.418899
# area_se                   0.385100
# symmetry_se               0.037119
# fractal_dimension_se      0.379975
# texture_worst             0.368366
# Name: concavity_worst, dtype: float64
#
#  texture_mean              0.295316
# symmetry_mean             0.430297
# fractal_dimension_mean    0.175325
# compactness_se            0.483208
# concavity_se              0.440472
# fractal_dimension_se      0.215204
# texture_worst             0.359755
# Name: concave points_worst, dtype: float64
#
#  diagnosis                 0.416294
# radius_mean               0.163953
# texture_mean              0.105008
# perimeter_mean            0.189115
# area_mean                 0.143570
# smoothness_mean           0.394309
# concavity_mean            0.409464
# concave points_mean       0.375744
# fractal_dimension_mean    0.334019
# radius_se                 0.094543
# perimeter_se              0.109930
# area_se                   0.074126
# compactness_se            0.277878
# concavity_se              0.197788
# concave points_se         0.143116
# symmetry_se               0.389402
# fractal_dimension_se      0.111094
# radius_worst              0.243529
# texture_worst             0.233027
# perimeter_worst           0.269493
# area_worst                0.209146
# smoothness_worst          0.493838
# Name: symmetry_worst, dtype: float64
#
#  diagnosis              0.323872
# radius_mean            0.007066
# texture_mean           0.119205
# perimeter_mean         0.051019
# area_mean              0.003738
# smoothness_mean        0.499316
# concave points_mean    0.368661
# symmetry_mean          0.438413
# radius_se              0.049559
# perimeter_se           0.085433
# area_se                0.017539
# smoothness_se          0.101480
# concavity_se           0.439329
# concave points_se      0.310655
# symmetry_se            0.078079
# radius_worst           0.093492
# texture_worst          0.219122
# perimeter_worst        0.138957
# area_worst             0.079647
# Name: fractal_dimension_worst, dtype: float64

# %%
# Negatively correlated features
corr_matrix.where(df.corr()<0)
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                      NaN          NaN           NaN             NaN
# radius_mean                    NaN          NaN           NaN             NaN
# texture_mean                   NaN          NaN           NaN             NaN
# perimeter_mean                 NaN          NaN           NaN             NaN
# area_mean                      NaN          NaN           NaN             NaN
# smoothness_mean                NaN          NaN     -0.023389             NaN
# compactness_mean               NaN          NaN           NaN             NaN
# concavity_mean                 NaN          NaN           NaN             NaN
# concave points_mean            NaN          NaN           NaN             NaN
# symmetry_mean                  NaN          NaN           NaN             NaN
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# radius_se                      NaN          NaN           NaN             NaN
# texture_se               -0.008303    -0.097317           NaN       -0.086761
# perimeter_se                   NaN          NaN           NaN             NaN
# area_se                        NaN          NaN           NaN             NaN
# smoothness_se            -0.067016    -0.222600           NaN       -0.202694
# compactness_se                 NaN          NaN           NaN             NaN
# concavity_se                   NaN          NaN           NaN             NaN
# concave points_se              NaN          NaN           NaN             NaN
# symmetry_se              -0.006522    -0.104321           NaN       -0.081629
# fractal_dimension_se           NaN    -0.042641           NaN       -0.005523
# radius_worst                   NaN          NaN           NaN             NaN
# texture_worst                  NaN          NaN           NaN             NaN
# perimeter_worst                NaN          NaN           NaN             NaN
# area_worst                     NaN          NaN           NaN             NaN
# smoothness_worst               NaN          NaN           NaN             NaN
# compactness_worst              NaN          NaN           NaN             NaN
# concavity_worst                NaN          NaN           NaN             NaN
# concave points_worst           NaN          NaN           NaN             NaN
# symmetry_worst                 NaN          NaN           NaN             NaN
# fractal_dimension_worst        NaN          NaN           NaN             NaN
#
#                          area_mean  smoothness_mean  compactness_mean  \
# diagnosis                      NaN              NaN               NaN
# radius_mean                    NaN              NaN               NaN
# texture_mean                   NaN        -0.023389               NaN
# perimeter_mean                 NaN              NaN               NaN
# area_mean                      NaN              NaN               NaN
# smoothness_mean                NaN              NaN               NaN
# compactness_mean               NaN              NaN               NaN
# concavity_mean                 NaN              NaN               NaN
# concave points_mean            NaN              NaN               NaN
# symmetry_mean                  NaN              NaN               NaN
# fractal_dimension_mean   -0.283110              NaN               NaN
# radius_se                      NaN              NaN               NaN
# texture_se               -0.066280              NaN               NaN
# perimeter_se                   NaN              NaN               NaN
# area_se                        NaN              NaN               NaN
# smoothness_se            -0.166777              NaN               NaN
# compactness_se                 NaN              NaN               NaN
# concavity_se                   NaN              NaN               NaN
# concave points_se              NaN              NaN               NaN
# symmetry_se              -0.072497              NaN               NaN
# fractal_dimension_se     -0.019887              NaN               NaN
# radius_worst                   NaN              NaN               NaN
# texture_worst                  NaN              NaN               NaN
# perimeter_worst                NaN              NaN               NaN
# area_worst                     NaN              NaN               NaN
# smoothness_worst               NaN              NaN               NaN
# compactness_worst              NaN              NaN               NaN
# concavity_worst                NaN              NaN               NaN
# concave points_worst           NaN              NaN               NaN
# symmetry_worst                 NaN              NaN               NaN
# fractal_dimension_worst        NaN              NaN               NaN
#
#                          concavity_mean  concave points_mean  symmetry_mean  \
# diagnosis                           NaN                  NaN            NaN
# radius_mean                         NaN                  NaN            NaN
# texture_mean                        NaN                  NaN            NaN
# perimeter_mean                      NaN                  NaN            NaN
# area_mean                           NaN                  NaN            NaN
# smoothness_mean                     NaN                  NaN            NaN
# compactness_mean                    NaN                  NaN            NaN
# concavity_mean                      NaN                  NaN            NaN
# concave points_mean                 NaN                  NaN            NaN
# symmetry_mean                       NaN                  NaN            NaN
# fractal_dimension_mean              NaN                  NaN            NaN
# radius_se                           NaN                  NaN            NaN
# texture_se                          NaN                  NaN            NaN
# perimeter_se                        NaN                  NaN            NaN
# area_se                             NaN                  NaN            NaN
# smoothness_se                       NaN                  NaN            NaN
# compactness_se                      NaN                  NaN            NaN
# concavity_se                        NaN                  NaN            NaN
# concave points_se                   NaN                  NaN            NaN
# symmetry_se                         NaN                  NaN            NaN
# fractal_dimension_se                NaN                  NaN            NaN
# radius_worst                        NaN                  NaN            NaN
# texture_worst                       NaN                  NaN            NaN
# perimeter_worst                     NaN                  NaN            NaN
# area_worst                          NaN                  NaN            NaN
# smoothness_worst                    NaN                  NaN            NaN
# compactness_worst                   NaN                  NaN            NaN
# concavity_worst                     NaN                  NaN            NaN
# concave points_worst                NaN                  NaN            NaN
# symmetry_worst                      NaN                  NaN            NaN
# fractal_dimension_worst             NaN                  NaN            NaN
#
#                                   ...             radius_worst  texture_worst  \
# diagnosis                         ...                      NaN            NaN
# radius_mean                       ...                      NaN            NaN
# texture_mean                      ...                      NaN            NaN
# perimeter_mean                    ...                      NaN            NaN
# area_mean                         ...                      NaN            NaN
# smoothness_mean                   ...                      NaN            NaN
# compactness_mean                  ...                      NaN            NaN
# concavity_mean                    ...                      NaN            NaN
# concave points_mean               ...                      NaN            NaN
# symmetry_mean                     ...                      NaN            NaN
# fractal_dimension_mean            ...                -0.253691      -0.051269
# radius_se                         ...                      NaN            NaN
# texture_se                        ...                -0.111690            NaN
# perimeter_se                      ...                      NaN            NaN
# area_se                           ...                      NaN            NaN
# smoothness_se                     ...                -0.230691      -0.074743
# compactness_se                    ...                      NaN            NaN
# concavity_se                      ...                      NaN            NaN
# concave points_se                 ...                      NaN            NaN
# symmetry_se                       ...                -0.128121      -0.077473
# fractal_dimension_se              ...                -0.037488      -0.003195
# radius_worst                      ...                      NaN            NaN
# texture_worst                     ...                      NaN            NaN
# perimeter_worst                   ...                      NaN            NaN
# area_worst                        ...                      NaN            NaN
# smoothness_worst                  ...                      NaN            NaN
# compactness_worst                 ...                      NaN            NaN
# concavity_worst                   ...                      NaN            NaN
# concave points_worst              ...                      NaN            NaN
# symmetry_worst                    ...                      NaN            NaN
# fractal_dimension_worst           ...                      NaN            NaN
#
#                          perimeter_worst  area_worst  smoothness_worst  \
# diagnosis                            NaN         NaN               NaN
# radius_mean                          NaN         NaN               NaN
# texture_mean                         NaN         NaN               NaN
# perimeter_mean                       NaN         NaN               NaN
# area_mean                            NaN         NaN               NaN
# smoothness_mean                      NaN         NaN               NaN
# compactness_mean                     NaN         NaN               NaN
# concavity_mean                       NaN         NaN               NaN
# concave points_mean                  NaN         NaN               NaN
# symmetry_mean                        NaN         NaN               NaN
# fractal_dimension_mean         -0.205151   -0.231854               NaN
# radius_se                            NaN         NaN               NaN
# texture_se                     -0.102242   -0.083195         -0.073658
# perimeter_se                         NaN         NaN               NaN
# area_se                              NaN         NaN               NaN
# smoothness_se                  -0.217304   -0.182195               NaN
# compactness_se                       NaN         NaN               NaN
# concavity_se                         NaN         NaN               NaN
# concave points_se                    NaN         NaN               NaN
# symmetry_se                    -0.103753   -0.110343         -0.012662
# fractal_dimension_se           -0.001000   -0.022736               NaN
# radius_worst                         NaN         NaN               NaN
# texture_worst                        NaN         NaN               NaN
# perimeter_worst                      NaN         NaN               NaN
# area_worst                           NaN         NaN               NaN
# smoothness_worst                     NaN         NaN               NaN
# compactness_worst                    NaN         NaN               NaN
# concavity_worst                      NaN         NaN               NaN
# concave points_worst                 NaN         NaN               NaN
# symmetry_worst                       NaN         NaN               NaN
# fractal_dimension_worst              NaN         NaN               NaN
#
#                          compactness_worst  concavity_worst  \
# diagnosis                              NaN              NaN
# radius_mean                            NaN              NaN
# texture_mean                           NaN              NaN
# perimeter_mean                         NaN              NaN
# area_mean                              NaN              NaN
# smoothness_mean                        NaN              NaN
# compactness_mean                       NaN              NaN
# concavity_mean                         NaN              NaN
# concave points_mean                    NaN              NaN
# symmetry_mean                          NaN              NaN
# fractal_dimension_mean                 NaN              NaN
# radius_se                              NaN              NaN
# texture_se                       -0.092439        -0.068956
# perimeter_se                           NaN              NaN
# area_se                                NaN              NaN
# smoothness_se                    -0.055558        -0.058298
# compactness_se                         NaN              NaN
# concavity_se                           NaN              NaN
# concave points_se                      NaN              NaN
# symmetry_se                            NaN              NaN
# fractal_dimension_se                   NaN              NaN
# radius_worst                           NaN              NaN
# texture_worst                          NaN              NaN
# perimeter_worst                        NaN              NaN
# area_worst                             NaN              NaN
# smoothness_worst                       NaN              NaN
# compactness_worst                      NaN              NaN
# concavity_worst                        NaN              NaN
# concave points_worst                   NaN              NaN
# symmetry_worst                         NaN              NaN
# fractal_dimension_worst                NaN              NaN
#
#                          concave points_worst  symmetry_worst  \
# diagnosis                                 NaN             NaN
# radius_mean                               NaN             NaN
# texture_mean                              NaN             NaN
# perimeter_mean                            NaN             NaN
# area_mean                                 NaN             NaN
# smoothness_mean                           NaN             NaN
# compactness_mean                          NaN             NaN
# concavity_mean                            NaN             NaN
# concave points_mean                       NaN             NaN
# symmetry_mean                             NaN             NaN
# fractal_dimension_mean                    NaN             NaN
# radius_se                                 NaN             NaN
# texture_se                          -0.119638       -0.128215
# perimeter_se                              NaN             NaN
# area_se                                   NaN             NaN
# smoothness_se                       -0.102007       -0.107342
# compactness_se                            NaN             NaN
# concavity_se                              NaN             NaN
# concave points_se                         NaN             NaN
# symmetry_se                         -0.030413             NaN
# fractal_dimension_se                      NaN             NaN
# radius_worst                              NaN             NaN
# texture_worst                             NaN             NaN
# perimeter_worst                           NaN             NaN
# area_worst                                NaN             NaN
# smoothness_worst                          NaN             NaN
# compactness_worst                         NaN             NaN
# concavity_worst                           NaN             NaN
# concave points_worst                      NaN             NaN
# symmetry_worst                            NaN             NaN
# fractal_dimension_worst                   NaN             NaN
#
#                          fractal_dimension_worst
# diagnosis                                    NaN
# radius_mean                                  NaN
# texture_mean                                 NaN
# perimeter_mean                               NaN
# area_mean                                    NaN
# smoothness_mean                              NaN
# compactness_mean                             NaN
# concavity_mean                               NaN
# concave points_mean                          NaN
# symmetry_mean                                NaN
# fractal_dimension_mean                       NaN
# radius_se                                    NaN
# texture_se                             -0.045655
# perimeter_se                                 NaN
# area_se                                      NaN
# smoothness_se                                NaN
# compactness_se                               NaN
# concavity_se                                 NaN
# concave points_se                            NaN
# symmetry_se                                  NaN
# fractal_dimension_se                         NaN
# radius_worst                                 NaN
# texture_worst                                NaN
# perimeter_worst                              NaN
# area_worst                                   NaN
# smoothness_worst                             NaN
# compactness_worst                            NaN
# concavity_worst                              NaN
# concave points_worst                         NaN
# symmetry_worst                               NaN
# fractal_dimension_worst                      NaN
#
# [31 rows x 31 columns]

# %%
for x,i in corr_matrix.iteritems():
    print('\n',pd.Series(i).where(pd.Series(i)<0).dropna())
# Out:
#  fractal_dimension_mean   -0.012838
# texture_se               -0.008303
# smoothness_se            -0.067016
# symmetry_se              -0.006522
# Name: diagnosis, dtype: float64
#
#  fractal_dimension_mean   -0.311631
# texture_se               -0.097317
# smoothness_se            -0.222600
# symmetry_se              -0.104321
# fractal_dimension_se     -0.042641
# Name: radius_mean, dtype: float64
#
#  smoothness_mean          -0.023389
# fractal_dimension_mean   -0.076437
# Name: texture_mean, dtype: float64
#
#  fractal_dimension_mean   -0.261477
# texture_se               -0.086761
# smoothness_se            -0.202694
# symmetry_se              -0.081629
# fractal_dimension_se     -0.005523
# Name: perimeter_mean, dtype: float64
#
#  fractal_dimension_mean   -0.283110
# texture_se               -0.066280
# smoothness_se            -0.166777
# symmetry_se              -0.072497
# fractal_dimension_se     -0.019887
# Name: area_mean, dtype: float64
#
#  texture_mean   -0.023389
# Name: smoothness_mean, dtype: float64
#
#  Series([], Name: compactness_mean, dtype: float64)
#
#  Series([], Name: concavity_mean, dtype: float64)
#
#  Series([], Name: concave points_mean, dtype: float64)
#
#  Series([], Name: symmetry_mean, dtype: float64)
#
#  diagnosis         -0.012838
# radius_mean       -0.311631
# texture_mean      -0.076437
# perimeter_mean    -0.261477
# area_mean         -0.283110
# area_se           -0.090170
# radius_worst      -0.253691
# texture_worst     -0.051269
# perimeter_worst   -0.205151
# area_worst        -0.231854
# Name: fractal_dimension_mean, dtype: float64
#
#  Series([], Name: radius_se, dtype: float64)
#
#  diagnosis                 -0.008303
# radius_mean               -0.097317
# perimeter_mean            -0.086761
# area_mean                 -0.066280
# radius_worst              -0.111690
# perimeter_worst           -0.102242
# area_worst                -0.083195
# smoothness_worst          -0.073658
# compactness_worst         -0.092439
# concavity_worst           -0.068956
# concave points_worst      -0.119638
# symmetry_worst            -0.128215
# fractal_dimension_worst   -0.045655
# Name: texture_se, dtype: float64
#
#  Series([], Name: perimeter_se, dtype: float64)
#
#  fractal_dimension_mean   -0.09017
# Name: area_se, dtype: float64
#
#  diagnosis              -0.067016
# radius_mean            -0.222600
# perimeter_mean         -0.202694
# area_mean              -0.166777
# radius_worst           -0.230691
# texture_worst          -0.074743
# perimeter_worst        -0.217304
# area_worst             -0.182195
# compactness_worst      -0.055558
# concavity_worst        -0.058298
# concave points_worst   -0.102007
# symmetry_worst         -0.107342
# Name: smoothness_se, dtype: float64
#
#  Series([], Name: compactness_se, dtype: float64)
#
#  Series([], Name: concavity_se, dtype: float64)
#
#  Series([], Name: concave points_se, dtype: float64)
#
#  diagnosis              -0.006522
# radius_mean            -0.104321
# perimeter_mean         -0.081629
# area_mean              -0.072497
# radius_worst           -0.128121
# texture_worst          -0.077473
# perimeter_worst        -0.103753
# area_worst             -0.110343
# smoothness_worst       -0.012662
# concave points_worst   -0.030413
# Name: symmetry_se, dtype: float64
#
#  radius_mean       -0.042641
# perimeter_mean    -0.005523
# area_mean         -0.019887
# radius_worst      -0.037488
# texture_worst     -0.003195
# perimeter_worst   -0.001000
# area_worst        -0.022736
# Name: fractal_dimension_se, dtype: float64
#
#  fractal_dimension_mean   -0.253691
# texture_se               -0.111690
# smoothness_se            -0.230691
# symmetry_se              -0.128121
# fractal_dimension_se     -0.037488
# Name: radius_worst, dtype: float64
#
#  fractal_dimension_mean   -0.051269
# smoothness_se            -0.074743
# symmetry_se              -0.077473
# fractal_dimension_se     -0.003195
# Name: texture_worst, dtype: float64
#
#  fractal_dimension_mean   -0.205151
# texture_se               -0.102242
# smoothness_se            -0.217304
# symmetry_se              -0.103753
# fractal_dimension_se     -0.001000
# Name: perimeter_worst, dtype: float64
#
#  fractal_dimension_mean   -0.231854
# texture_se               -0.083195
# smoothness_se            -0.182195
# symmetry_se              -0.110343
# fractal_dimension_se     -0.022736
# Name: area_worst, dtype: float64
#
#  texture_se    -0.073658
# symmetry_se   -0.012662
# Name: smoothness_worst, dtype: float64
#
#  texture_se      -0.092439
# smoothness_se   -0.055558
# Name: compactness_worst, dtype: float64
#
#  texture_se      -0.068956
# smoothness_se   -0.058298
# Name: concavity_worst, dtype: float64
#
#  texture_se      -0.119638
# smoothness_se   -0.102007
# symmetry_se     -0.030413
# Name: concave points_worst, dtype: float64
#
#  texture_se      -0.128215
# smoothness_se   -0.107342
# Name: symmetry_worst, dtype: float64
#
#  texture_se   -0.045655
# Name: fractal_dimension_worst, dtype: float64

# %% [markdown]
# We tend to drop features having very strong correlation. Why? Think and try to write the answer. I will write this question's answer in week 3 module.

# %% [markdown]
# #### considering correlation between two or more features is 1.00 it is advisable to keep only one of those as
# ##### 1. Increases the computation speed
# ##### 2. Accuracy of model is not affected

# %% [markdown]
# #### (Optional) Step 8: Create a heatmap of the correlated features (helps in visualization)

# %%
# ----- step 8 -----
plt.figure(figsize=(18,18))
sns.heatmap(corr_matrix, linewidths = 0.05, cmap='jet', square = True, annot=True, fmt='0.1f')

# %% [markdown]
# That is all for week 2! We will learn about various algorithms in week 3 and implement them. See you next week!

# %% [markdown]
# All the best!
